# %% [markdown]
# ## Setup supporting packages

# %%
from arcgis.gis import GIS
from arcgis.features import FeatureLayer
from arcgis.geocoding import geocode

import requests

# %% [markdown]
# ## HUC12 of interest

# %%
#huc12 = '051302030106' # Tennessee
huc12 = '010900010704'

# %% [markdown]
# # Query ArcGIS based watershed web service

# %%
huc_result = None

lyr_url = 'https://inlandwaters.geoplatform.gov/arcgis/rest/services/NHDPlus/WatershedBoundaryDataset/MapServer/10'
huc12_conus = FeatureLayer(lyr_url)

huc_result = huc12_conus.query(where="HUC12='" + huc12 + "'", 
                                    out_fields='*',out_sr=4326)
huc_result.sdf
# Out:
#       AREAACRES    AREASQKM GNIS_ID         HUC12 HUMOD HUTYPE LOADDATE  \
# 0  36639.444604  148.274556    None  010900010704    PD      F      NaT
#
#   METASOURCEID                                 NAME  NONCONTRIBUTINGAREAACRES  \
# 0         None  Charles River-Frontal Boston Harbor                         0
#
#    ...  OBJECTID                                              SHAPE  \
# 0  ...     79751  {"rings": [[[-71.25066850628518, 42.3499071889...
#
#      SHAPE_Area   SHAPE_Length  SOURCEDATADESC SOURCEFEATUREID  \
# 0  2.714994e+08  153951.448827            None            None
#
#   SOURCEORIGINATOR STATES    TNMID TOHUC
# 0             None     MA  -334536  None
#
# [1 rows x 21 columns]

# %% [markdown]
# ## Display watershed result on map

# %%
gis = GIS()
map1 = gis.map()
map1.basemap = "gray"
map1.height = '650px'
map1.clear_graphics()

huc_symbol = {
  "type": "esriSFS",
  "color": [230, 76, 0, 50],
  "outline": {
    "type": "esriSLS",
    "color": [0, 0, 0, 255],
    "width": 0.75,
    "style": "esriSLSSolid"
  },
  "style": "esriSFSSolid"
}

map1.draw(huc_result,symbol=huc_symbol)

map1.extent = huc_result.sdf.spatial.full_extent

map1
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-743cb9a1-5faf-4905-82b9-c0f318be5416"><img src=""></img></div>

# %% [markdown]
# ## Retrieve ATTAINS assessment LINES from ATTAINS ArcGIS based web service (this is NOT the approach as it does not conform to the NHDPlus WBD to Catchment crosswalk)

# %%
from arcgis.geometry import filters

attains_lines_result = None

lines_lyr_url = 'https://inlandwaters.geoplatform.gov/arcgis/rest/services/ATTAINS_Geo/ATTAINS_Assessments/MapServer/1'
attains_lines_featurelayer = FeatureLayer(lines_lyr_url)
attains_lines_result = attains_lines_featurelayer.query(out_fields='*', out_sr=4326,
                                                 geometry_filter=filters.intersects(huc_result.features[0].geometry))

attains_lines_result.sdf
# Out:
#         OBJECTID algal_growth ammonia assessmentunitidentifier  \
# 0              1         None    None             NE-MT1-L0135
# 1              2         None    None             NE-LB1-L0020
# 2              3         None    None             NE-BB3-L0050
# 3              4         None    None             NE-MT1-L0023
# 4              5         None    None             NE-BB1-10000
# 5              6         None    None             NE-NE2-L0195
# 6              7         None    None             NE-RE1-L0040
# 7              8         None    None             NE-MT1-10250
# 8              9         None    None             NE-MT2-L0060
# 9             10         None    None             NE-BB1-L0040
# 10            11         None    None             NE-LP1-L0060
# 11            12         None    None             NE-SP1-L0070
# 12            13         None    None             NE-WH1-11820
# 13            14         None    None             NE-LO1-L0130
# 14            15         None    None             NE-MT2-12500
# 15            16         None    None             NE-MT2-10100
# 16            17         None    None             NE-RE1-10200
# 17            18         None    None             NE-WH1-11300
# 18            19         None    None             NE-RE3-L0060
# 19            20         None    None             NE-NI3-L0070
# 20            21         None    None             NE-EL1-21000
# 21            22         None    None             NE-LO4-L0010
# 22            23         None    None             NE-MP2-20400
# 23            24         None    None             NE-MP2-L0430
# 24            25         None   Cause             NE-LP2-L0260
# 25            26         None    None             NE-LB2-10100
# 26            27         None    None             NE-NE2-12330
# 27            28         None    None             NE-LP2-L0060
# 28            29         None    None             NE-LO4-10100
# 29            30         None    None             NE-BB1-L0100
# ...          ...          ...     ...                      ...
# 256913    257081         None    None              NY1201-0133
# 256914    257082         None    None              NY1201-0134
# 256915    257083         None    None              NY1201-0135
# 256916    257084         None    None              NY1201-0136
# 256917    257085         None    None              NY1201-0137
# 256918    257086         None    None              NY1201-0138
# 256919    257087         None    None              NY1201-0139
# 256920    257088         None    None              NY1201-0140
# 256921    257089         None    None              NY1201-0141
# 256922    257090         None    None              NY1201-0142
# 256923    257091        Cause    None              NY1301-0140
# 256924    257092         None    None              NY1301-0141
# 256925    257093         None    None              NY1301-0142
# 256926    257094         None    None              NY1301-0143
# 256927    257095         None    None              NY1301-0144
# 256928    257096         None    None              NY1301-0145
# 256929    257097         None    None              NY1301-0146
# 256930    257098         None    None              NY1301-0147
# 256931    257099         None    None              NY1301-0148
# 256932    257100        Cause    None              NY1301-0149
# 256933    257101         None    None              NY1301-0150
# 256934    257102         None    None              NY1301-0151
# 256935    257103         None    None              NY1301-0152
# 256936    257104         None    None              NY1301-0153
# 256937    257105         None    None              NY1301-0154
# 256938    257106         None    None              NY1301-0155
# 256939    257107         None    None              NY1301-0156
# 256940    257108         None    None              NY1301-0157
# 256941    257109         None    None              NY1301-0158
# 256942    257110         None    None              NY1301-0159
#
#                                  assessmentunitname biotoxins cause_unknown  \
# 0                                 PRAIRIE VIEW LAKE      None          None
# 1                    CRYSTAL SPRINGS NORTHWEST LAKE      None          None
# 2                                     LAKE HASTINGS      None          None
# 3                          HALLECK PARK (PAPILLION)      None          None
# 4                                    BIG BLUE RIVER      None          None
# 5                               MAYBERRY LAKE (WMA)      None          None
# 6                                HOLDREGE PARK LAKE      None          None
# 7                              WEST PAPILLION CREEK      None          None
# 8                       PLAINVIEW COUNTRY CLUB LAKE     Cause          None
# 9                                    ARROWHEAD LAKE      None          None
# 10      JERRY NEWMAN LAKE (PLATTE RIVER STATE PARK)      None          None
# 11                       EAST SUTHERLAND LAKE (WMA)      None          None
# 12                                   WEST ASH CREEK     Cause          None
# 13                                       PIBEL LAKE      None          None
# 14                                     BAZILE CREEK     Cause          None
# 15                                        ELK CREEK     Cause          None
# 16                                       LOST CREEK     Cause          None
# 17                                    CHADRON CREEK     Cause          None
# 18          HUGH BUTLER LAKE (RED WILLOW RESERVOIR)      None          None
# 19                                   CUB CREEK LAKE      None          None
# 20                                       ROCK CREEK     Cause          None
# 21                               RAVENNA LAKE (SRA)      None          None
# 22                                       PLUM CREEK      None          None
# 23                  BLUE HOLE LAKE (ELM CREEK)(WMA)      None          None
# 24                                   WEST TWIN LAKE      None          None
# 25                                  BIG SANDY CREEK      None          None
# 26                                LONG BRANCH CREEK      None          None
# 27                                         OAK LAKE      None          None
# 28                                        MUD CREEK      None          None
# 29                           WALNUT CREEK LAKE (2A)      None          None
# ...                                             ...       ...           ...
# 256913                                Rockwood Lake      None          None
# 256914               Sprite Creek, Lower, and tribs      None          None
# 256915               Sprite Creek, Upper, and tribs      None          None
# 256916                                     Mud Lake      None          None
# 256917                         Peck Creek and tribs      None          None
# 256918                           Tribs to Peck Lake      None          None
# 256919                              Vandenburg Pond      None          None
# 256920                               Woodworth Lake      None          None
# 256921                                   Hinds Pond      None          None
# 256922                                Mountain Lake      None          None
# 256923                                 Wallace Pond      None          None
# 256924                      Canopus Creek and tribs      None          None
# 256925                                 Lake Celeste      None          None
# 256926                                  Indian Lake      None          None
# 256927                               Cortlandt Lake      None          None
# 256928                    Canopus Lake, Pelton Lake      None          None
# 256929                                 Gregory Pond      None          None
# 256930                               Lake Peekskill      None          None
# 256931                         Mud Lake, Clear Lake      None          None
# 256932                                 Lake Mohegan      None          None
# 256933                                  Oceola Lake      None          None
# 256934                                  Bryant Pond      None          None
# 256935                     Wiccopee Brook and tribs      None          None
# 256936                           Wiccopee Reservoir      None          None
# 256937                  Tribs to Wiccopee Reservoir      None          None
# 256938                              Stillwater Pond      None          None
# 256939                                    Lake Ossi      None          None
# 256940                             Dickiebusch Lake      None          None
# 256941                                  Brocey Pond      None          None
# 256942                                 Hessian Lake      None          None
#
#        cause_unknown_fish_kills cause_unknown_impaired_biota chlorine  ...  \
# 0                          None                         None     None  ...
# 1                          None                         None     None  ...
# 2                          None                         None     None  ...
# 3                          None                         None     None  ...
# 4                          None                         None     None  ...
# 5                          None                         None     None  ...
# 6                          None                         None     None  ...
# 7                          None                         None     None  ...
# 8                          None                         None     None  ...
# 9                          None                         None     None  ...
# 10                         None                         None     None  ...
# 11                         None                         None     None  ...
# 12                         None                         None     None  ...
# 13                         None                         None     None  ...
# 14                         None                         None     None  ...
# 15                         None                         None     None  ...
# 16                         None                         None     None  ...
# 17                         None                         None     None  ...
# 18                         None                         None     None  ...
# 19                         None                         None     None  ...
# 20                         None                        Cause     None  ...
# 21                         None                         None     None  ...
# 22                         None                        Cause     None  ...
# 23                         None                         None     None  ...
# 24                         None                         None     None  ...
# 25                         None                         None     None  ...
# 26                         None                        Cause     None  ...
# 27                         None                         None     None  ...
# 28                         None                        Cause     None  ...
# 29                         None                         None     None  ...
# ...                         ...                          ...      ...  ...
# 256913                     None                         None     None  ...
# 256914                     None                         None     None  ...
# 256915                     None                         None     None  ...
# 256916                     None                         None     None  ...
# 256917                     None                         None     None  ...
# 256918                     None                         None     None  ...
# 256919                     None                         None     None  ...
# 256920                     None                         None     None  ...
# 256921                     None                         None     None  ...
# 256922                     None                         None     None  ...
# 256923                     None                         None     None  ...
# 256924                     None                         None     None  ...
# 256925                     None                         None     None  ...
# 256926                     None                         None     None  ...
# 256927                     None                         None     None  ...
# 256928                     None                         None     None  ...
# 256929                     None                         None     None  ...
# 256930                     None                         None     None  ...
# 256931                     None                         None     None  ...
# 256932                     None                         None     None  ...
# 256933                     None                         None     None  ...
# 256934                     None                         None     None  ...
# 256935                     None                         None     None  ...
# 256936                     None                         None     None  ...
# 256937                     None                         None     None  ...
# 256938                     None                         None     None  ...
# 256939                     None                         None     None  ...
# 256940                     None                         None     None  ...
# 256941                     None                         None     None  ...
# 256942                     None                         None     None  ...
#
#        state                            submissionid taste_color_and_odor  \
# 0         NE  {c92ee4b6-0fb4-a64a-556c-e98040793b15}                 None
# 1         NE  {c92ee4b6-0fb4-a64a-556c-e98040793b15}                 None
# 2         NE  {c92ee4b6-0fb4-a64a-556c-e98040793b15}                 None
# 3         NE  {c92ee4b6-0fb4-a64a-556c-e98040793b15}                 None
# 4         NE  {c92ee4b6-0fb4-a64a-556c-e98040793b15}                 None
# 5         NE  {c92ee4b6-0fb4-a64a-556c-e98040793b15}                 None
# 6         NE  {c92ee4b6-0fb4-a64a-556c-e98040793b15}                 None
# 7         NE  {c92ee4b6-0fb4-a64a-556c-e98040793b15}                 None
# 8         NE  {c92ee4b6-0fb4-a64a-556c-e98040793b15}                 None
# 9         NE  {c92ee4b6-0fb4-a64a-556c-e98040793b15}                 None
# 10        NE  {c92ee4b6-0fb4-a64a-556c-e98040793b15}                 None
# 11        NE  {c92ee4b6-0fb4-a64a-556c-e98040793b15}                 None
# 12        NE  {c92ee4b6-0fb4-a64a-556c-e98040793b15}                 None
# 13        NE  {c92ee4b6-0fb4-a64a-556c-e98040793b15}                 None
# 14        NE  {c92ee4b6-0fb4-a64a-556c-e98040793b15}                 None
# 15        NE  {c92ee4b6-0fb4-a64a-556c-e98040793b15}                 None
# 16        NE  {c92ee4b6-0fb4-a64a-556c-e98040793b15}                 None
# 17        NE  {c92ee4b6-0fb4-a64a-556c-e98040793b15}                 None
# 18        NE  {c92ee4b6-0fb4-a64a-556c-e98040793b15}                 None
# 19        NE  {c92ee4b6-0fb4-a64a-556c-e98040793b15}                 None
# 20        NE  {c92ee4b6-0fb4-a64a-556c-e98040793b15}                 None
# 21        NE  {c92ee4b6-0fb4-a64a-556c-e98040793b15}                 None
# 22        NE  {c92ee4b6-0fb4-a64a-556c-e98040793b15}                 None
# 23        NE  {c92ee4b6-0fb4-a64a-556c-e98040793b15}                 None
# 24        NE  {c92ee4b6-0fb4-a64a-556c-e98040793b15}                 None
# 25        NE  {c92ee4b6-0fb4-a64a-556c-e98040793b15}                 None
# 26        NE  {c92ee4b6-0fb4-a64a-556c-e98040793b15}                 None
# 27        NE  {c92ee4b6-0fb4-a64a-556c-e98040793b15}                 None
# 28        NE  {c92ee4b6-0fb4-a64a-556c-e98040793b15}                 None
# 29        NE  {c92ee4b6-0fb4-a64a-556c-e98040793b15}                 None
# ...      ...                                     ...                  ...
# 256913    NY  {f894344e-7181-d1d6-9526-fe1ebb3b9b12}                 None
# 256914    NY  {f894344e-7181-d1d6-9526-fe1ebb3b9b12}                 None
# 256915    NY  {f894344e-7181-d1d6-9526-fe1ebb3b9b12}                 None
# 256916    NY  {f894344e-7181-d1d6-9526-fe1ebb3b9b12}                 None
# 256917    NY  {f894344e-7181-d1d6-9526-fe1ebb3b9b12}                 None
# 256918        None         None             None           None  None
# 256919        None         None             None           None  None
# 256920        None         None             None           None  None
# 256921        None         None             None           None  None
# 256922        None         None             None           None  None
# 256923        None         None             None           None  None
# 256924        None         None             None           None  None
# 256925        None         None             None           None  None
# 256926        None         None             None           None  None
# 256927        None         None             None           None  None
# 256928        None         None             None           None  None
# 256929        None         None             None           None  None
# 256930        None         None             None           None  None
# 256931        None         None             None           None  None
# 256932        None         None             None           None  None
# 256933        None         None             None           None  None
# 256934        None         None             None           None  None
# 256935        None         None             None           None  None
# 256936        None         None             None           None  None
# 256937        None         None             None           None  None
# 256938        None         None             None           None  None
# 256939        None         None             None           None  None
# 256940        None         None             None           None  None
# 256941        None         None             None           None  None
# 256942        None         None             None           None  None
#
#        turbidity visionpriority303d
# 0           None                  N
# 1           None                  N
# 2           None                  N
# 3           None                  N
# 4           None                  N
# 5           None                  N
# 6           None                  N
# 7           None                  N
# 8           None                  N
# 9           None                  N
# 10          None                  N
# 11          None                  N
# 12          None                  Y
# 13          None                  N
# 14          None                  Y
# 15          None                  Y
# 16          None                  Y
# 17          None                  Y
# 18          None                  N
# 19          None                  N
# 20          None                  Y
# 21          None                  N
# 22          None                  N
# 23          None                  N
# 24          None                  N
# 25          None                  Y
# 26          None                  N
# 27          None                  N
# 28          None                  N
# 29          None                  N
# ...          ...                ...
# 256913      None                  N
# 256914      None                  N
# 256915      None                  N
# 256916      None                  N
# 256917      None                  N
# 256918      None                  N
# 256919      None                  N
# 256920      None                  N
# 256921      None                  N
# 256922      None                  N
# 256923      None                  N
# 256924      None                  N
# 256925      None                  N
# 256926      None                  N
# 256927      None                  N
# 256928      None                  N
# 256929      None                  N
# 256930      None                  N
# 256931      None                  N
# 256932      None                  N
# 256933      None                  N
# 256934      None                  N
# 256935      None                  N
# 256936      None                  N
# 256937      None                  N
# 256938      None                  N
# 256939      None                  N
# 256940      None                  N
# 256941      None                  N
# 256942      None                  N
#
# [256943 rows x 57 columns]

# %% [markdown]
# ## Show assessments from direct spatial query

# %%
gis = GIS()
map2 = gis.map()
map2.basemap = "gray"
map2.height = '650px'
map2.clear_graphics()

symbol_attains = {
    "color": [
        0,
        92,
        230,
        255
    ],
    "width": 2,
    "type": "esriSLS",
    "style": "esriSLSSolid"
}

map2.draw(huc_result,symbol=huc_symbol)

map2.draw(attains_result,symbol=symbol_attains)

map2.extent = attains_result.sdf.spatial.full_extent

map2
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-3aa5704d-cb7a-43fa-9967-ef8cd7513fef"><img src=""></img></div>

# %% [markdown]
# ## Retrieve assessments from ATTAINS Java based web service

# %%
url = 'http://54.209.48.156/attains-public/api/huc12summary?huc=' + huc12
print(url)
response = requests.get(url)        # To execute get request 
#print(response.status_code)     # To print http response code  
#print(response.text)            # To print formatted JSON response 

data = response.json()

assessmentUnits = data['items'][0]['assessmentUnits']

assessmentUnitList = []
for unit in assessmentUnits:
    assessmentUnitList.append(unit['assessmentUnitId'])

assessmentUnitList = ",".join(map(lambda x: "'" + str(x) + "'",assessmentUnitList))
assessmentUnitList
# Out:
# http://54.209.48.156/attains-public/api/huc12summary?huc=010900010704
# ''

# %% [markdown]
# ## Retrieve linear features from ArcGIS based on assessment list

# %%
from arcgis.geometry import filters

lyr_url = 'https://inlandwaters.geoplatform.gov/arcgis/rest/services/BETA/hmw_cip/MapServer/1'
attains_lines_featurelayer = FeatureLayer(lyr_url)
query_result3 = attains_lines_featurelayer.query(where="assessmentunitidentifier in (" + assessmentUnitList + ")", 
                                                 out_fields='*',out_sr=4326)

query_result3.sdf
# Out:
#    OBJECTID                                              SHAPE  Shape_Length  \
# 0         5  {"paths": [[[-76.9667505038364, 38.87766563515...   1806.020444
# 1         9  {"paths": [[[-76.9534825065659, 38.86617797618...    668.726683
# 2        11  {"paths": [[[-76.94546523758953, 38.8862434426...    750.146112
# 3        14  {"paths": [[[-76.94936394748217, 38.9130061189...   2268.004148
# 4        19  {"paths": [[[-76.95356791029826, 38.9067868554...   5764.890523
# 5        20  {"paths": [[[-76.95753384381857, 38.9059979239...    522.760347
# 6        21  {"paths": [[[-76.9634179059476, 38.86311088822...   1289.339591
# 7        22  {"paths": [[[-76.96914131606617, 38.9170628668...   1968.783871
# 8        23  {"paths": [[[-76.97693208831835, 38.8574268728...   1186.674177
# 9        24  {"paths": [[[-76.96316734605192, 38.8820414342...   2916.979367
#
#   abnormalflow acidity ammonia assessmentunitidentifier  \
# 0         None    None    None              DCTPB01R_00
# 1         None    None    None              DCTFD01R_00
# 2         None    None    None              DCTFC01R_00
# 3        Cause    None    None              DCTNA01R_00
# 4        Cause   Cause    None              DCTWB00R_02
# 5        Cause    None    None              DCTWB00R_01
# 6        Cause    None    None              DCTTX27R_00
# 7        Cause    None    None              DCTHR01R_00
# 8         None    None    None              DCTFS01R_00
# 9         None    None    None              DCTDU01R_00
#
#          assessmentunitname bacteriaandothermicrobes biologicalpoisons  \
# 0  POPES BRANCH (HAWES RUN)                    Cause              None
# 1      FORT DAVIS TRIBUTARY                    Cause              None
# 2          FORT CHAPLIN RUN                    Cause              None
# 3                  NASH RUN                    Cause              None
# 4           WATTS BRANCH DC                    Cause              None
# 5           WATTS BRANCH DC                    Cause              None
# 6    TEXAS AVENUE TRIBUTARY                    Cause              None
# 7                HICKEY RUN                    Cause              None
# 8    FORT STANTON TRIBUTARY                    Cause              None
# 9         FORT DUPONT CREEK                    Cause              None
#
#          ...         reportingcycle salts state tastecolorandodor temperature  \
# 0        ...                   2020  None    DC              None        None
# 1        ...                   2020  None    DC              None        None
# 2        ...                   2020  None    DC              None        None
# 3        ...                   2020  None    DC              None        None
# 4        ...                   2020  None    DC              None        None
# 5        ...                   2020  None    DC              None        None
# 6        ...                   2020  None    DC              None        None
# 7        ...                   2020  None    DC              None        None
# 8        ...                   2020  None    DC              None        None
# 9        ...                   2020  None    DC              None        None
#
#   totaltoxicchemicals toxicinorganicchemicals     toxicorganicchemicals trash  \
# 0                None                    None                     Cause  None
# 1                None                    None                      None  None
# 2                None                    None                      None  None
# 3                None                    None                     Cause  None
# 4                None                    None  Insufficient Information  None
# 5                None                    None  Insufficient Information  None
# 6                None                    None                     Cause  None
# 7                None                    None                     Cause  None
# 8                None                    None                     Cause  None
# 9                None                    None                      None  None
#
#   visionpriority303d
# 0                  Y
# 1                  Y
# 2                  Y
# 3                  Y
# 4                  Y
# 5                  Y
# 6                  Y
# 7                  Y
# 8                  Y
# 9                  Y
#
# [10 rows x 55 columns]

# %% [markdown]
# ## Display linear features on map

# %%
gis = GIS()
map3 = gis.map()
map3.basemap = "gray"
map3.height = '650px'
map3.clear_graphics()

symbol = {
    "color": [
        0,
        92,
        230,
        255
    ],
    "width": 2,
    "type": "esriSLS",
    "style": "esriSLSSolid"
}

map3.draw(query_result3,symbol=symbol)

map3.extent = query_result3.sdf.spatial.full_extent

map3
# Out:
# MapView(layout=Layout(height='400px', width='100%'))

# %% [markdown]
# ## Retrieve point features from ArcGIS based on assessment list

# %%
from arcgis.geometry import filters

lyr_url = 'https://inlandwaters.geoplatform.gov/arcgis/rest/services/BETA/hmw_cip/MapServer/0'
attains_point_featurelayer = FeatureLayer(lyr_url)
query_result4 = attains_point_featurelayer.query(where="assessmentunitidentifier in (" + assessmentUnitList + ")", 
                                                 out_fields='*',out_sr=4326)

if len(query_result4.features) == 0:
    print("No point features found.")
else:
    query_result4.sdf
# Out:
# No point features found.

# %%
if len(query_result4.features) == 0:
    print("No point features found.")
else:
    gis = GIS()
    map4 = gis.map()
    map4.basemap = "gray"
    map4.height = '650px'
    map4.clear_graphics()

    symbol = {
        "color": [
            0,
            92,
            230,
            255
        ],
        "width": 2,
        "type": "esriSLS",
        "style": "esriSLSSolid"
    }

    map4.draw(query_result4,symbol=symbol)

    map4.extent = query_result4.sdf.spatial.full_extent

    map4
# Out:
# No point features found.

# %% [markdown]
# ## Retrieve area features from ArcGIS based on assessment list

# %%
from arcgis.geometry import filters

lyr_url = 'https://inlandwaters.geoplatform.gov/arcgis/rest/services/BETA/hmw_cip/MapServer/2'
attains_area_featurelayer = FeatureLayer(lyr_url)
query_result5 = attains_area_featurelayer.query(where="assessmentunitidentifier in (" + assessmentUnitList + ")", 
                                                 out_fields='*',out_sr=4326)

print(str(query_result5))

if len(query_result5.features) == 0:
    print("No area features found.")
else:
    query_result5.sdf
# Out:
# {"features": [{"geometry": {"rings": [[[-76.97944572899354, 38.8775942904239], [-76.9793449694597, 38.87762191248607], [-76.97882819023631, 38.877756818321224], [-76.97563198265878, 38.87850024902246], [-76.97540715590274, 38.878589652048966], [-76.974887258627, 38.8787426152104], [-76.97456439602905, 38.87885620097714], [-76.97428030831205, 38.87897814127485], [-76.97410767187735, 38.87905314412901], [-76.9740162853652, 38.87912226707872], [-76.97375658241654, 38.879383453793146], [-76.97363015801504, 38.87946218004469], [-76.97327196018539, 38.87977008411757], [-76.97320195178034, 38.879974001002054], [-76.97319495570092, 38.88017685296246], [-76.9731457082604, 38.880258779040474], [-76.97300558365251, 38.880441355378935], [-76.97275981447223, 38.88084196657399], [-76.972078769316, 38.881786049464324], [-76.97172078079382, 38.8823237110277], [-76.97062514516763, 38.88377936918393], [-76.9704073189826, 38.88381007680539], [-76.9701056709984, 38.88392329434984], [-76.96999316599221, 38.8840107913492], [-76.96995111495544, 38.88409259413178], [-76.96993681647108, 38.88420096043705], [-76.96929063762595, 38.88440108160227], [-76.9692204459646, 38.88442929